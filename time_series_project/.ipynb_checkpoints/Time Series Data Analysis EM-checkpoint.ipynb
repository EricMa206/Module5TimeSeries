# %% [markdown]
# ## Time Series Analysis

# %% [markdown]
# ### Sunspot history monthly
#
#
#
#
# ---

# %%
# Load required libraries
# %matplotlib inline 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from pandas import Grouper
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARMA

# %%
data = pd.read_csv('monthly-sunspots.csv')

# %%
# Change to date-time
data['Month'] = pd.to_datetime(data['Month'])
data.set_index('Month', inplace= True)
data.head(20)
# Out:
#             Sunspots
# Month
# 1749-01-01      58.0
# 1749-02-01      62.6
# 1749-03-01      70.0
# 1749-04-01      55.7
# 1749-05-01      85.0
# 1749-06-01      83.5
# 1749-07-01      94.8
# 1749-08-01      66.3
# 1749-09-01      75.9
# 1749-10-01      75.5
# 1749-11-01     158.6
# 1749-12-01      85.2
# 1750-01-01      73.3
# 1750-02-01      75.9
# 1750-03-01      89.2
# 1750-04-01      88.3
# 1750-05-01      90.0
# 1750-06-01     100.0
# 1750-07-01      85.4
# 1750-08-01     103.0

# %%
data.describe()
# Out:
#           Sunspots
# count  2820.000000
# mean     51.265957
# std      43.448971
# min       0.000000
# 25%      15.700000
# 50%      42.000000
# 75%      74.925000
# max     253.800000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2820 entries, 1749-01-01 to 1983-12-01
# Data columns (total 1 columns):
# Sunspots    2820 non-null float64
# dtypes: float64(1)
# memory usage: 44.1 KB

# %%
data.plot(figsize=(12,8), title='Monthly Sunspot Data 1749', fontsize=14)

# %%
period_11y_group = data.groupby(Grouper(freq='11A'))
period_11y_group.plot(figsize=(10,1));
# Out:
# /Users/ericma/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
#create a function that will help us to quickly 
def test_stationarity(timeseries, window):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=window).mean()
    rolstd = timeseries.rolling(window=window).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries.iloc[window:], color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
# Credit Dmitriy Sergeev 
# https://medium.com/open-machine-learning-course/open-machine-learning-course-topic-9-time-series-analysis-in-python-a270cb05e0b3
def plotMovingAverage(series, window, plot_intervals=False, scale=1.96, plot_anomalies=False):

    """
        series - dataframe with timeseries
        window - rolling window size 
        plot_intervals - show confidence intervals
        plot_anomalies - show anomalies 
    """
    rolling_mean = series.rolling(window=window).mean()

    plt.figure(figsize=(15,5))
    plt.title("Moving average\n window size = {}".format(window))
    plt.plot(rolling_mean, "g", label="Rolling mean trend")

    # Plot confidence intervals for smoothed values
    if plot_intervals:
        mae = mean_absolute_error(series[window:], rolling_mean[window:])
        deviation = np.std(series[window:] - rolling_mean[window:])
        lower_bond = rolling_mean - (mae + scale * deviation)
        upper_bond = rolling_mean + (mae + scale * deviation)
        plt.plot(upper_bond, "r--", label="Upper Bond / Lower Bond")
        plt.plot(lower_bond, "r--")
        
        # Having the intervals, find abnormal values
        if plot_anomalies:
            anomalies = pd.DataFrame(index=series.index, columns=series.columns)
            anomalies[series<lower_bond] = series[series<lower_bond]
            anomalies[series>upper_bond] = series[series>upper_bond]
            plt.plot(anomalies, "ro", markersize=10)
        
    plt.plot(series[window:], label="Actual values")
    plt.legend(loc="upper left")
    plt.grid(True)

# %%
#test the stationarity of the untransformed dataset
test_stationarity(data['Sunspots'], 128)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -9.430541e+00
# p-value                        5.204466e-16
# #Lags Used                     2.700000e+01
# Number of Observations Used    2.660000e+03
# Critical Value (1%)           -3.432811e+00
# Critical Value (5%)           -2.862627e+00
# Critical Value (10%)          -2.567349e+00
# dtype: float64

# %%
annual_spots = data.resample('y').sum()
annual_spots = pd.DataFrame(annual_spots, columns=['Sunspots'])
annual_spots.plot(figsize=(12,8), title= 'Annual Sunspots', fontsize=14)

# %%
# spec=spectrum(num,spans=c(5,5))

# %%
# First difference
data['first_difference'] = data['Sunspots'] - data['Sunspots'].shift(1)  
test_stationarity(data.first_difference.dropna(inplace=False), 128)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.339634e+00
# p-value                        3.202043e-13
# #Lags Used                     2.300000e+01
# Number of Observations Used    2.663000e+03
# Critical Value (1%)           -3.432808e+00
# Critical Value (5%)           -2.862626e+00
# Critical Value (10%)          -2.567348e+00
# dtype: float64

# %%
# Seasonal First difference
data['seasonal_first_difference'] = data['Sunspots'] - data['Sunspots'].shift(132)
test_stationarity(data.seasonal_first_difference.dropna(inplace=False), 1320)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.218759e+00
# p-value                        6.515411e-13
# #Lags Used                     2.600000e+01
# Number of Observations Used    2.661000e+03
# Critical Value (1%)           -3.432810e+00
# Critical Value (5%)           -2.862627e+00
# Critical Value (10%)          -2.567349e+00
# dtype: float64

# %%
# ACF and PACF on original data
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
#plot the ACF
fig = sm.graphics.tsa.plot_acf(data['Sunspots'].iloc[1:], lags=60, ax=ax1)
ax2 = fig.add_subplot(212)
#plot the PACF
fig = sm.graphics.tsa.plot_pacf(data['Sunspots'].iloc[1:], lags=60, ax=ax2)

# %%
# ACF and PACF on first difference
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
# plot the ACF
fig = sm.graphics.tsa.plot_acf(data['first_difference'].iloc[1:], lags=60, ax=ax1, zero=False)
ax2 = fig.add_subplot(212)
# plot the PACF
fig = sm.graphics.tsa.plot_pacf(data['first_difference'].iloc[1:], lags=60, ax=ax2, zero=False)

# %%
data.dropna(inplace=True)

# %%
# Seasonal decompose with 128 mo years as period
decomposition_mo = seasonal_decompose(data['Sunspots'], freq=128)
fig = plt.figure()
fig = decomposition_mo.plot()
fig.set_size_inches(15, 8)

# %%
annual_spots = data.resample('y').sum()
annual_spots = pd.DataFrame(annual_spots, columns=['Sunspots'])
# annual_spots.plot(figsize=(12,8), title= 'Annual Sunspots', fontsize=14)
plotMovingAverage(data, window=128, plot_intervals=True)

# %%
# Seasonal decompose with 11 years as period
decomposition = seasonal_decompose(annual_spots['Sunspots'], freq=11)
fig = plt.figure()
fig = decomposition.plot()
fig.set_size_inches(15, 8)

# %%
annual_spots.index.min()
# Out:
# Timestamp('1760-12-31 00:00:00', freq='A-DEC')

# %%
# Fit an MA(1) model to the first simulated data
mod_arma = ARMA(annual_spots['Sunspots'], order=(0,1))
res_arma = mod_arma.fit()

# Print out summary information on the fit
print(res_arma.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:               Sunspots   No. Observations:                  235
# Model:                     ARMA(0, 1)   Log Likelihood               -1681.942
# Method:                       css-mle   S.D. of innovations            309.849
# Date:                Fri, 12 Jul 2019   AIC                           3369.884
# Time:                        15:18:13   BIC                           3380.263
# Sample:                    12-31-1749   HQIC                          3374.068
#                          - 12-31-1983
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            615.0065     36.320     16.933      0.000     543.821     686.192
# ma.L1.Sunspots     0.8003      0.029     27.699      0.000       0.744       0.857
#                                     Roots
# ...

# %%
annual_spots['forecast_arma'] = res_arma.predict(start = 200, end= 400, dynamic= False)

annual_spots[['Sunspots', 'forecast_arma']].plot(figsize=(16, 12))

# %%
mod = sm.tsa.statespace.SARIMAX(data['Sunspots'], trend='n', order=(1,0,2), seasonal_order=(0,1,0,128))
res = mod.fit()
print(res.summary())
# Out:
# /Users/ericma/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/statespace/representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]
#                            Statespace Model Results
# ...
# Dep. Variable:               Sunspots   No. Observations:                  235
# Model:               SARIMAX(0, 1, 1)   Log Likelihood               -1625.637
# Date:                Fri, 12 Jul 2019   AIC                           3255.274
# Time:                        15:13:02   BIC                           3262.185
# Sample:                    12-31-1749   HQIC                          3258.061
#                          - 12-31-1983
# Covariance Type:                  opg
# ...

# %%
annual_spots['validate_sarimax'] = res.predict(start = 200, end= 400, dynamic= False)  
annual_spots[['Sunspots', 'validate']].plot(figsize=(16, 12))

# %%
mod = sm.tsa.statespace.SARIMAX(annual_spots['Sunspots'], trend='n', order=(1,0,2), seasonal_order=(0,1,0,132))
res = mod.fit()
print(res.summary())
# Out:
#                                   Statespace Model Results
# ...
# Dep. Variable:                            Sunspots   No. Observations:                  224
# Model:             SARIMAX(1, 0, 2)x(0, 1, 0, 128)   Log Likelihood                -685.809
# Date:                             Mon, 15 Jul 2019   AIC                           1379.617
# Time:                                     10:30:15   BIC                           1389.875
# Sample:                                 12-31-1760   HQIC                          1383.764
#                                       - 12-31-1983
# Covariance Type:                               opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5830      0.105      5.576      0.000       0.378       0.788
# ma.L1          0.9221      0.095      9.669      0.000       0.735       1.109
# ...

# %%
annual_spots['validate_sarimax'] = res.predict(start = 200, end= 400, dynamic= False)  
annual_spots[['Sunspots', 'validate_sarimax']].plot(figsize=(16, 12))

# %%
mod = sm.tsa.statespace.SARIMAX(annual_spots['Sunspots'], trend='n', order=(1,0,2), seasonal_order=(0,1,0,132))
res = mod.fit()
print(res.summary())
# Out:
#                                   Statespace Model Results
# ...
# Dep. Variable:                            Sunspots   No. Observations:                  224
# Model:             SARIMAX(1, 0, 2)x(0, 1, 0, 132)   Log Likelihood                -660.374
# Date:                             Mon, 15 Jul 2019   AIC                           1328.747
# Time:                                     10:31:43   BIC                           1338.834
# Sample:                                 12-31-1760   HQIC                          1332.819
#                                       - 12-31-1983
# Covariance Type:                               opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6173      0.142      4.361      0.000       0.340       0.895
# ma.L1          0.7156      0.147      4.861      0.000       0.427       1.004
# ...
